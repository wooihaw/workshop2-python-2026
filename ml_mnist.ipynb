# %% [markdown]
# ### MNIST Classification using Machine Learning
# <img src="https://raw.githubusercontent.com/wooihaw/ml_dl_comparison/main/ml_mnist.jpg" width="800" height="300">

# %%
# Initialization
# %matplotlib inline
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, ConfusionMatrixDisplay
from tensorflow.keras.datasets import mnist
from sklearn.preprocessing import StandardScaler

# %%
# ------------------------------------------------------------
# Load the MNIST dataset (from Keras)
# ------------------------------------------------------------
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Flatten 28x28 images into 784-dimensional vectors
X_train = X_train.reshape(X_train.shape[0], -1)
X_test = X_test.reshape(X_test.shape[0], -1)

# %%
# ------------------------------------------------------------
# Feature Scaling
# ------------------------------------------------------------
# To do: Use StandardScaler for feature scaling
scl = StandardScaler()
Xs_train = scl.fit_transform(X_train)
Xs_test = scl.transform(X_test)

# %%
# ------------------------------------------------------------
# Build the MLPClassifier model
# ------------------------------------------------------------
# To do: build and train MLPClassifier with two hidden layers of 128 and 64 neurons for max 30 iterations, respectively
mpc = MLPClassifier(hidden_layer_sizes=(128, 64), verbose=True, max_iter=30, random_state=42).fit(Xs_train, y_train)

# %%
# ------------------------------------------------------------
# Evaluate the model
# ------------------------------------------------------------
# To do:
# i. Evaluate the overall acuuracy using the scaled testing set
# ii. Print the classification report
print(f'mpc accuracy: {mpc.score(Xs_test, y_test):.3%}')

y_pred = mpc.predict(Xs_test)
report = classification_report(y_test, y_pred)
print(report)

# %%
# ------------------------------------------------------------
# Confusion Matrix for MLPClassifier
# ------------------------------------------------------------
# To do: Plot confusion matrix
ConfusionMatrixDisplay.from_predictions(y_test, y_pred, cmap='Blues')
